# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import smote_variants as sv
import imbalanced_databases as imbd

from sklearn.datasets import make_classification
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import logging
logging.getLogger('smote_variants').setLevel(logging.CRITICAL)

import warnings
warnings.filterwarnings("ignore")

import mldb.binary_classification as binclas

# %%
datasets= binclas.get_filtered_data_loaders(n_attr_encoded_bounds=[1, 20], n_bounds=[1, 800], n_minority_bounds=[10, 1000])

# %%
datasets= [binclas.load_cleveland_0_vs_4,
binclas.load_ecoli_0_1_4_6_vs_5,
binclas.load_ecoli4,
binclas.load_glass_0_1_4_6_vs_2,
binclas.load_glass2,
binclas.load_shuttle_6_vs_2_3,
binclas.load_habarman,
binclas.load_iris0,
binclas.load_new_thyroid1,
binclas.load_bupa,
binclas.load_appendicitis,
binclas.load_led7digit_0_2_4_5_6_7_8_9_vs_1,
binclas.load_page_blocks_1_3_vs_4,
binclas.load_winequality_red_3_vs_5,
binclas.load_yeast_1_vs_7,
binclas.load_pima,
binclas.load_wisconsin,
binclas.load_monk_2,
binclas.load_saheart,
binclas.load_australian,
binclas.load_abalone_3_vs_11]

#datasets = [binclas.load_bupa]

# %%
len(datasets)
# Out:
# 21

# %%
oversamplers_metric= set(sv.get_metric_learning_oversamplers())
oversamplers_ml = {sv.SPY, sv.OUPS, sv.SMOTE_D, sv.NT_SMOTE,
                sv.Gazzah, sv.ROSE, sv.NDO_sampling,
                sv.Borderline_SMOTE1, sv.SMOTE,
                sv.Borderline_SMOTE2, sv.ISMOTE, sv.SMMO,
                sv.SMOTE_OUT, sv.SN_SMOTE, sv.Selected_SMOTE,
                sv.distance_SMOTE, sv.Gaussian_SMOTE, sv.MCT,
                sv.Random_SMOTE, sv.ADASYN, sv.SL_graph_SMOTE,
                sv.CURE_SMOTE, sv.ANS, sv.MSMOTE,
                sv.Safe_Level_SMOTE, sv.SMOBD, sv.CBSO,
                sv.Assembled_SMOTE, sv.SDSMOTE,
                sv.SMOTE_TomekLinks, sv.Edge_Det_SMOTE,
                sv.ProWSyn, sv.Stefanowski, sv.NRAS,
                sv.AND_SMOTE, sv.DBSMOTE, sv.polynom_fit_SMOTE,
                sv.ASMOBD, sv.MDO}
#oversamplers = [sv.SMOTE, sv.SMOTE_TomekLinks, sv.SMOTE_ENN, sv.E_SMOTE]
oversamplers = [sv.SMOTE]

# %%
validator = RepeatedStratifiedKFold(n_repeats=1000, n_splits=5, random_state=5)

classifiers= [(DecisionTreeClassifier, {'random_state': 5}), 
                #(RandomForestClassifier, {'random_state': 5}),
                #(RandomForestClassifier, {'random_state': 5, 'min_samples_leaf': 15}),
                (SVC, {'probability': True, 'random_state': 5, 'C': 1.0}),
                #(KNeighborsClassifier, {'algorithm': 'brute', 'weights': 'distance'})
                (KNeighborsClassifier, {'algorithm': 'brute', 'weights': 'distance', 'n_neighbors': 5})
                ]

# %%
results= []

for j, dataset in enumerate(datasets):
    """
    X, y= make_classification(n_samples=100, 
                                n_features=4,
                                n_informative=2,
                                n_redundant=1,
                                n_repeated=0,
                                n_clusters_per_class=2,
                                weights=np.array([0.8, 0.2]),
                                random_state=j)
    ds= {'name': str(j)}
    """

    results_dataset= []

    ds= dataset()
    X, y= ds['data'], ds['target']

    print(j, ds['name'], len(X), len(np.unique(X, axis=0)), len(X[y == 1]))

    for i, (train, test) in enumerate(validator.split(X, y)):
        X_train, y_train = X[train], y[train]
        X_test, y_test = X[test], y[test]

        nn_params_0= {'metric': 'precomputed',
                        'metric_learning_method': 'id',
                        'algorithm': 'brute'}
        nn_params_1= {'metric': 'precomputed',
                    'metric_learning_method': 'gmean',
                    'algorithm': 'brute'}

        #metric_tensor= sv.MetricTensor(**nn_params_1).tensor(X_train, y_train)
        #nn_params_1['metric_tensor']= metric_tensor

        oversampler_params_0= {'random_state': 5,
                                'nn_params': nn_params_0,
                                'sampling_params': {'simplex_sampling': 'uniform',
                                                    'within_simplex_sampling': 'random',
                                                    'n_dim': 2},
                                'n_neighbors': 5,
                                'proportion': 1.0}
        oversampler_params_1= {'random_state': 5,
                                'nn_params': nn_params_0,
                                'n_neighbors': 5,
                                'sampling_params': {'simplex_sampling': 'uniform',
                                                    'within_simplex_sampling': 'deterministic',
                                                    'n_dim': 2},
                                'proportion': 1.0}

        for o in oversamplers:
            if not o.__name__.endswith('NoSMOTE'):
                oversampler= o(**oversampler_params_0)
            else:
                oversampler= o()
            X_os_0, y_os_0 = oversampler.sample(X_train, y_train)

            for c, cp in classifiers:
                classifier = c(**cp).fit(X_os_0, y_os_0)
                y_proba_0 = classifier.predict_proba(oversampler.preprocessing_transform(X_test))[:,1]
                results_dataset.append([i, o.__name__, 'euc', roc_auc_score(y_test, y_proba_0), ds['name'], c.__name__, cp])
                #print(results_dataset[-1])

            if not o.__name__.endswith('NoSMOTE'):
                oversampler= o(**oversampler_params_1)
            else:
                oversampler= o()
            X_os_1, y_os_1 = oversampler.sample(X_train, y_train)

            for c, cp in classifiers:
                classifier = c(**cp).fit(X_os_1, y_os_1)
                y_proba_1 = classifier.predict_proba(oversampler.preprocessing_transform(X_test))[:,1]
                results_dataset.append([i, o.__name__, 'euc_pref', roc_auc_score(y_test, y_proba_1), ds['name'], c.__name__, cp])

    data= pd.DataFrame(results_dataset, columns=['fold', 'oversampler', 'metric', 'auc', 'dataset', 'classifier', 'params'])
    print(data.groupby(['classifier', 'oversampler', 'metric']).agg({'auc': np.mean}))

    results.extend(results_dataset)
    
    data= pd.DataFrame(results, columns=['fold', 'oversampler', 'metric', 'auc', 'dataset', 'classifier', 'params'])
    print(data.groupby(['classifier', 'oversampler', 'metric']).agg({'auc': np.mean}))
# Out:
# 0 cleveland-0_vs_4 177 177 13
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.781554
#                                    euc_pref  0.786560
# KNeighborsClassifier   SMOTE       euc       0.970327
#                                    euc_pref  0.969877
# SVC                    SMOTE       euc       0.978641
#                                    euc_pref  0.978311
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.781554
#                                    euc_pref  0.786560
# KNeighborsClassifier   SMOTE       euc       0.970327
#                                    euc_pref  0.969877
# SVC                    SMOTE       euc       0.978641
#                                    euc_pref  0.978311
# 1 ecoli-0-1-4-6_vs_5 280 280 20
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.842783
#                                    euc_pref  0.850306
# KNeighborsClassifier   SMOTE       euc       0.918767
#                                    euc_pref  0.918672
# SVC                    SMOTE       euc       0.962321
#                                    euc_pref  0.962024
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.812168
#                                    euc_pref  0.818433
# KNeighborsClassifier   SMOTE       euc       0.944547
#                                    euc_pref  0.944274
# SVC                    SMOTE       euc       0.970481
#                                    euc_pref  0.970167
# 2 ecoli4 336 336 20
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.877068
#                                    euc_pref  0.878974
# KNeighborsClassifier   SMOTE       euc       0.943890
#                                    euc_pref  0.943972
# SVC                    SMOTE       euc       0.990827
#                                    euc_pref  0.991049
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.833801
#                                    euc_pref  0.838613
# KNeighborsClassifier   SMOTE       euc       0.944328
#                                    euc_pref  0.944174
# SVC                    SMOTE       euc       0.977263
#                                    euc_pref  0.977128
# 3 glass-0-1-4-6_vs_2 205 204 17
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.658277
#                                    euc_pref  0.655767
# KNeighborsClassifier   SMOTE       euc       0.785035
#                                    euc_pref  0.783477
# SVC                    SMOTE       euc       0.831052
#                                    euc_pref  0.832235
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.789920
#                                    euc_pref  0.792902
# KNeighborsClassifier   SMOTE       euc       0.904505
#                                    euc_pref  0.904000
# SVC                    SMOTE       euc       0.940710
#                                    euc_pref  0.940905
# 4 glass2 214 213 17
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.680616
#                                    euc_pref  0.681792
# KNeighborsClassifier   SMOTE       euc       0.810388
#                                    euc_pref  0.812237
# SVC                    SMOTE       euc       0.833583
#                                    euc_pref  0.832961
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.768059
#                                    euc_pref  0.770680
# KNeighborsClassifier   SMOTE       euc       0.885682
#                                    euc_pref  0.885647
# SVC                    SMOTE       euc       0.919285
#                                    euc_pref  0.919316
# 5 shuttle-6_vs_2-3 230 230 10
#                                                 auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       1.0000
#                                    euc_pref  1.0000
# KNeighborsClassifier   SMOTE       euc       0.9946
#                                    euc_pref  0.9946
# SVC                    SMOTE       euc       1.0000
#                                    euc_pref  1.0000
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.806716
#                                    euc_pref  0.808900
# KNeighborsClassifier   SMOTE       euc       0.903835
#                                    euc_pref  0.903806
# SVC                    SMOTE       euc       0.932737
#                                    euc_pref  0.932763
# 6 habarman 306 283 81
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.570957
#                                    euc_pref  0.573939
# KNeighborsClassifier   SMOTE       euc       0.628114
#                                    euc_pref  0.627328
# SVC                    SMOTE       euc       0.688473
#                                    euc_pref  0.688843
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.773036
#                                    euc_pref  0.775334
# KNeighborsClassifier   SMOTE       euc       0.864446
#                                    euc_pref  0.864309
# SVC                    SMOTE       euc       0.897842
#                                    euc_pref  0.897918
# 7 iris0 150 147 50
#                                              auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       1.0
#                                    euc_pref  1.0
# KNeighborsClassifier   SMOTE       euc       1.0
#                                    euc_pref  1.0
# SVC                    SMOTE       euc       1.0
#                                    euc_pref  1.0
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.801407
#                                    euc_pref  0.803417
# KNeighborsClassifier   SMOTE       euc       0.881390
#                                    euc_pref  0.881270
# SVC                    SMOTE       euc       0.910612
#                                    euc_pref  0.910678
# 8 new_thyroid1 215 215 35
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.953944
#                                    euc_pref  0.954666
# KNeighborsClassifier   SMOTE       euc       0.995085
#                                    euc_pref  0.995499
# SVC                    SMOTE       euc       0.999431
#                                    euc_pref  0.999437
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.818355
#                                    euc_pref  0.820223
# KNeighborsClassifier   SMOTE       euc       0.894023
#                                    euc_pref  0.893962
# SVC                    SMOTE       euc       0.920481
#                                    euc_pref  0.920540
# 9 bupa 345 341 145
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.624677
#                                    euc_pref  0.623767
# KNeighborsClassifier   SMOTE       euc       0.671395
#                                    euc_pref  0.669655
# SVC                    SMOTE       euc       0.734204
#                                    euc_pref  0.733500
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.798988
#                                    euc_pref  0.800577
# KNeighborsClassifier   SMOTE       euc       0.871760
#                                    euc_pref  0.871532
# SVC                    SMOTE       euc       0.901853
#                                    euc_pref  0.901836
# 10 appendicitis 106 106 21
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.708168
#                                    euc_pref  0.712379
# KNeighborsClassifier   SMOTE       euc       0.789327
#                                    euc_pref  0.790056
# SVC                    SMOTE       euc       0.845417
#                                    euc_pref  0.846136
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.790731
#                                    euc_pref  0.792559
# KNeighborsClassifier   SMOTE       euc       0.864266
#                                    euc_pref  0.864125
# SVC                    SMOTE       euc       0.896723
#                                    euc_pref  0.896772
# 11 led7digit-0-2-4-6-7-8-9_vs_1 443 83 37
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.890109
#                                    euc_pref  0.890109
# KNeighborsClassifier   SMOTE       euc       0.900545
#                                    euc_pref  0.673022
# SVC                    SMOTE       euc       0.937934
#                                    euc_pref  0.939360
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.799013
#                                    euc_pref  0.800688
# KNeighborsClassifier   SMOTE       euc       0.867290
#                                    euc_pref  0.848200
# SVC                    SMOTE       euc       0.900157
#                                    euc_pref  0.900321
# 12 page-blocks-1-3_vs_4 472 455 28
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.992775
#                                    euc_pref  0.992755
# KNeighborsClassifier   SMOTE       euc       0.995279
#                                    euc_pref  0.995164
# SVC                    SMOTE       euc       0.990120
#                                    euc_pref  0.990176
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.813918
#                                    euc_pref  0.815463
# KNeighborsClassifier   SMOTE       euc       0.877135
#                                    euc_pref  0.859505
# SVC                    SMOTE       euc       0.907077
#                                    euc_pref  0.907233
# 13 winequality-red-3_vs_5 691 587 10
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.511552
#                                    euc_pref  0.505702
# KNeighborsClassifier   SMOTE       euc       0.674324
#                                    euc_pref  0.673827
# SVC                    SMOTE       euc       0.657024
#                                    euc_pref  0.657321
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.792320
#                                    euc_pref  0.793337
# KNeighborsClassifier   SMOTE       euc       0.862648
#                                    euc_pref  0.846242
# SVC                    SMOTE       euc       0.889216
#                                    euc_pref  0.889382
# 14 yeast-1_vs_7 459 455 30
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.644129
#                                    euc_pref  0.655063
# KNeighborsClassifier   SMOTE       euc       0.760268
#                                    euc_pref  0.761538
# SVC                    SMOTE       euc       0.774034
#                                    euc_pref  0.773379
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.782441
#                                    euc_pref  0.784119
# KNeighborsClassifier   SMOTE       euc       0.855823
#                                    euc_pref  0.840595
# SVC                    SMOTE       euc       0.881537
#                                    euc_pref  0.881649
# 15 pima 768 768 268
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.672865
#                                    euc_pref  0.673823
# KNeighborsClassifier   SMOTE       euc       0.772327
#                                    euc_pref  0.773245
# SVC                    SMOTE       euc       0.823016
#                                    euc_pref  0.822852
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.775592
#                                    euc_pref  0.777225
# KNeighborsClassifier   SMOTE       euc       0.850605
#                                    euc_pref  0.836386
# SVC                    SMOTE       euc       0.877880
#                                    euc_pref  0.877974
# 16 wisconsin 683 449 239
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.936891
#                                    euc_pref  0.936160
# KNeighborsClassifier   SMOTE       euc       0.986195
#                                    euc_pref  0.986262
# SVC                    SMOTE       euc       0.987843
#                                    euc_pref  0.987782
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.785080
#                                    euc_pref  0.786574
# KNeighborsClassifier   SMOTE       euc       0.858580
#                                    euc_pref  0.845202
# SVC                    SMOTE       euc       0.884348
#                                    euc_pref  0.884433
# 17 monk-2 432 432 204
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       1.000000
#                                    euc_pref  0.999917
# KNeighborsClassifier   SMOTE       euc       0.971946
#                                    euc_pref  0.971838
# SVC                    SMOTE       euc       0.991971
#                                    euc_pref  0.992159
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.797020
#                                    euc_pref  0.798427
# KNeighborsClassifier   SMOTE       euc       0.864879
#                                    euc_pref  0.852237
# SVC                    SMOTE       euc       0.890327
#                                    euc_pref  0.890418
# 18 saheart 462 462 160
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.590002
#                                    euc_pref  0.589269
# KNeighborsClassifier   SMOTE       euc       0.667117
#                                    euc_pref  0.667881
# SVC                    SMOTE       euc       0.730066
#                                    euc_pref  0.729794
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.786125
#                                    euc_pref  0.787418
# KNeighborsClassifier   SMOTE       euc       0.854470
#                                    euc_pref  0.842534
# SVC                    SMOTE       euc       0.881892
#                                    euc_pref  0.881964
# 19 australian 690 690 307
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.808151
#                                    euc_pref  0.807090
# KNeighborsClassifier   SMOTE       euc       0.894228
#                                    euc_pref  0.894526
# SVC                    SMOTE       euc       0.918392
#                                    euc_pref  0.918458
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.787226
#                                    euc_pref  0.788402
# KNeighborsClassifier   SMOTE       euc       0.856458
#                                    euc_pref  0.845134
# SVC                    SMOTE       euc       0.883717
#                                    euc_pref  0.883789
# 20 abalone-3_vs_11 502 502 15
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.995510
#                                    euc_pref  0.995510
# KNeighborsClassifier   SMOTE       euc       0.999096
#                                    euc_pref  0.999096
# SVC                    SMOTE       euc       0.999997
#                                    euc_pref  0.999997
#                                                   auc
# classifier             oversampler metric
# DecisionTreeClassifier SMOTE       euc       0.797144
#                                    euc_pref  0.798264
# KNeighborsClassifier   SMOTE       euc       0.863250
#                                    euc_pref  0.852465
# SVC                    SMOTE       euc       0.889255
#                                    euc_pref  0.889323

# %%
data= pd.DataFrame(results, columns=['fold', 'oversampler', 'metric', 'auc', 'dataset'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/pandas/core/internals/construction.py:982, in _finalize_columns_and_data(content, columns, dtype)
#     981 try:
# --> 982     columns = _validate_or_indexify_columns(contents, columns)
#     983 except AssertionError as err:
#     984     # GH#26429 do not raise user-facing AssertionError
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/pandas/core/internals/construction.py:1030, in _validate_or_indexify_columns(content, columns)
#    1028 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1029     # caller's responsibility to check for this...
# -> 1030     raise AssertionError(
#    1031         f"{len(columns)} columns passed, passed data had "
#    1032         f"{len(content)} columns"
#    1033     )
#    1034 elif is_mi_list:
#    1035
#    1036     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 5 columns passed, passed data had 7 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /home/gykovacs/workspaces/smote_variants/notebooks/experiments/00_metric_learning.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/smote_variants/notebooks/experiments/00_metric_learning.ipynb#ch0000007vscode-remote?line=0'>1</a> data= pd.DataFrame(results, columns=['fold', 'oversampler', 'metric', 'auc', 'dataset'])
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/pandas/core/frame.py:721, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     716     if columns is not None:
#     717         # error: Argument 1 to "ensure_index" has incompatible type
#     718         # "Collection[Any]"; expected "Union[Union[Union[ExtensionArray,
#     719         # ndarray], Index, Series], Sequence[Any]]"
#     720         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 721     arrays, columns, index = nested_data_to_arrays(
#     722         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     723         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     724         data,
#     725         columns,
#     726         index,  # type: ignore[arg-type]
#     727         dtype,
#     728     )
#     729     mgr = arrays_to_mgr(
#     730         arrays,
#     731         columns,
#    (...)
#     734         typ=manager,
#     735     )
#     736 else:
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/pandas/core/internals/construction.py:519, in nested_data_to_arrays(data, columns, index, dtype)
#     516 if is_named_tuple(data[0]) and columns is None:
#     517     columns = ensure_index(data[0]._fields)
# --> 519 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     520 columns = ensure_index(columns)
#     522 if index is None:
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/pandas/core/internals/construction.py:883, in to_arrays(data, columns, dtype)
#     880     data = [tuple(x) for x in data]
#     881     arr = _list_to_arrays(data)
# --> 883 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     884 return content, columns
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/pandas/core/internals/construction.py:985, in _finalize_columns_and_data(content, columns, dtype)
#     982     columns = _validate_or_indexify_columns(contents, columns)
#     983 except AssertionError as err:
#     984     # GH#26429 do not raise user-facing AssertionError
# --> 985     raise ValueError(err) from err
#     987 if len(contents) and contents[0].dtype == np.object_:
#     988     contents = _convert_object_array(contents, dtype=dtype)
#
# ValueError: 5 columns passed, passed data had 7 columns

# %%
tmp= np.hstack([X_train[:,2:], X_train[:,:2]]).T

# %%
mt= sv.MetricTensor(metric='precomputed', metric_learning_method='gmean').tensor(X_train, y_train)
eigv, eigw= np.linalg.eig(mt)
print(eigv)
# Out:
# [0.41862514 0.31411729 0.28807286 0.25696997 0.20078851 0.16538174
#  0.1450392  0.05703713 0.11517736 0.07665949 0.08368331 0.09854955
#  0.09670926]

# %%
mt= sv.MetricTensor(metric='precomputed', metric_learning_method='gmean').tensor(tmp, y_train)
eigv, eigw= np.linalg.eig(mt)
print(eigv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/gykovacs/workspaces/smote_variants/notebooks/experiments/00_metric_learning.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/smote_variants/notebooks/experiments/00_metric_learning.ipynb#ch0000010vscode-remote?line=0'>1</a> mt= sv.MetricTensor(metric='precomputed', metric_learning_method='gmean').tensor(tmp, y_train)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/smote_variants/notebooks/experiments/00_metric_learning.ipynb#ch0000010vscode-remote?line=1'>2</a> eigv, eigw= np.linalg.eig(mt)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/smote_variants/notebooks/experiments/00_metric_learning.ipynb#ch0000010vscode-remote?line=2'>3</a> print(eigv)
#
# File ~/workspaces/smote_variants/smote_variants/_metric_tensor.py:353, in MetricTensor.tensor(self, X, y)
#     339     self.metric_tensor= NCA().fit(X_mod, y_mod).get_mahalanobis_matrix()
#     340 elif self.metric_learning_method == 'gmean':
#     341     #m_itml= ITML_Supervised(random_state=5).fit(X_mod, y_mod).get_mahalanobis_matrix()
#     342     #eig_itml, _= np.linalg.eig(m_itml)
#    (...)
#     350     #print(m_mi)
#     351     #print('-----')
# --> 353     matrices = [ITML_Supervised(random_state=i, prior='random').fit(X_mod, y_mod).get_mahalanobis_matrix() for i in range(2)]
#     355     #self.metric_tensor= psd_mean([m_itml, m_lsml])
#     356     self.metric_tensor= psd_mean(matrices)
#
# File ~/workspaces/smote_variants/smote_variants/_metric_tensor.py:353, in <listcomp>(.0)
#     339     self.metric_tensor= NCA().fit(X_mod, y_mod).get_mahalanobis_matrix()
#     340 elif self.metric_learning_method == 'gmean':
#     341     #m_itml= ITML_Supervised(random_state=5).fit(X_mod, y_mod).get_mahalanobis_matrix()
#     342     #eig_itml, _= np.linalg.eig(m_itml)
#    (...)
#     350     #print(m_mi)
#     351     #print('-----')
# --> 353     matrices = [ITML_Supervised(random_state=i, prior='random').fit(X_mod, y_mod).get_mahalanobis_matrix() for i in range(2)]
#     355     #self.metric_tensor= psd_mean([m_itml, m_lsml])
#     356     self.metric_tensor= psd_mean(matrices)
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/metric_learn/itml.py:378, in ITML_Supervised.fit(self, X, y, bounds)
#     375   num_constraints = 20 * num_classes**2
#     377 c = Constraints(y)
# --> 378 pos_neg = c.positive_negative_pairs(num_constraints,
#     379                                     random_state=self.random_state)
#     380 pairs, y = wrap_pairs(X, pos_neg)
#     381 return _BaseITML._fit(self, pairs, y, bounds=bounds)
#
# File ~/anaconda3/envs/smote_variants/lib/python3.10/site-packages/metric_learn/constraints.py:75, in Constraints.positive_negative_pairs(self, num_constraints, same_length, random_state)
#      72 random_state = check_random_state(random_state)
#      73 a, b = self._pairs(num_constraints, same_label=True,
#      74                    random_state=random_state)
# ---> 75 c, d = self._pairs(num_constraints, same_label=False,
#      76                    random_state=random_state)
#      77 if same_length and len(a) != len(c):
#      78   n = min(len(a), len(c))
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
data.groupby(['oversampler', 'metric']).agg({'auc': np.mean})
# Out:
#                                 auc
# oversampler       metric
# ADASYN            ITML_mi  0.847245
#                   euc      0.846558
# Borderline_SMOTE1 ITML_mi  0.841936
#                   euc      0.839512
# Borderline_SMOTE2 ITML_mi  0.840883
#                   euc      0.837899
# SMOTE             ITML_mi  0.851753
#                   euc      0.849281
# SMOTE_TomekLinks  ITML_mi  0.852887
#                   euc      0.848034

# %%
data.groupby(['dataset', 'oversampler', 'metric']).agg({'auc': np.mean})
# Out:
#                                                 auc
# dataset         oversampler       metric
# abalone-3_vs_11 ADASYN            ITML_mi  0.999794
#                                   euc      1.000000
#                 Borderline_SMOTE1 ITML_mi  0.999794
#                                   euc      0.999863
#                 Borderline_SMOTE2 ITML_mi  0.999794
# ...                                             ...
# yeast-1_vs_7    Borderline_SMOTE2 euc      0.776872
#                 SMOTE             ITML_mi  0.756919
#                                   euc      0.756545
#                 SMOTE_TomekLinks  ITML_mi  0.761913
#                                   euc      0.756758
#
# [210 rows x 1 columns]
