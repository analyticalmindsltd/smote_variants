# %% [markdown]
# # Evaluation of oversamplers with a set of classifiers on a set of datasets
#
# In this notebook, we give an example of evaluating multiple oversamplers on multiple datasets with multiple classifiers.

# %%
import os.path

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

import smote_variants as sv

import imbalanced_databases as imbd
# Out:
# 2022-08-14 19:55:00.175318: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-14 19:55:00.179542: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-14 19:55:00.179556: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Setting the cache_path which is used for caching during the evaluation

cache_path= os.path.join(os.path.expanduser('~'), 'smote_test')

if not os.path.exists(cache_path):
    os.makedirs(cache_path)

# %%
# Specifying two datasets by their load functions

datasets= [imbd.load_glass0(), imbd.load_yeast1()]

# %%
# Specifying the classifiers used for evaluation

classifiers = [('sklearn.neighbors', 'KNeighborsClassifier', {}),
                ('sklearn.tree', 'DecisionTreeClassifier', {})]

# %%
oversamplers = [('smote_variants', 'SMOTE_ENN', {}),
                ('smote_variants', 'NEATER', {}),
                ('smote_variants', 'Lee', {})]

# %%
# Executing the evaluation using 5 parallel jobs, and at most 35 different 
# random but meaningful parameter combinations with the oversamplers

results= sv.evaluation.evaluate_oversamplers(datasets=datasets,
                                    oversamplers=oversamplers,
                                    classifiers=classifiers,
                                    cache_path=cache_path,
                                    n_jobs=2)
# Out:
# 2022-08-14 19:55:04.235335: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-14 19:55:04.238994: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-14 19:55:04.239035: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-14 19:55:04.248881: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-14 19:55:04.252658: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-14 19:55:04.252695: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-14 19:55:06,403:INFO:SMOTE_ENN: Running sampling via ('SMOTE_ENN', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'SMOTE_ENN'}")
# 2022-08-14 19:55:06,403:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,403:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,403:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,404:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,404:INFO:EditedNearestNeighbors: Running noise removal
# 2022-08-14 19:55:06,405:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,405:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,410:INFO:SMOTE_ENN: returning copies for ENN removed too many samples
# 2022-08-14 19:55:06,413:INFO:NEATER: Running sampling via ('NEATER', "{'proportion': 1.0, 'smote_n_neighbors': 5, 'b': 5, 'alpha': 0.1, 'h': 20, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:06,414:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,414:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,414:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,415:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,416:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:06,416:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,417:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,418:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,418:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,419:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,420:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,420:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,448:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:06,448:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,449:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,449:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,450:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,450:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,451:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,451:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,454:INFO:SMOTE_ENN: Running sampling via ('SMOTE_ENN', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'SMOTE_ENN'}")
# 2022-08-14 19:55:06,454:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,454:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,455:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,456:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,456:INFO:EditedNearestNeighbors: Running noise removal
# 2022-08-14 19:55:06,457:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,457:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,466:INFO:SMOTE_ENN: returning copies for ENN removed too many samples
# 2022-08-14 19:55:06,471:INFO:NEATER: Running sampling via ('NEATER', "{'proportion': 1.0, 'smote_n_neighbors': 5, 'b': 5, 'alpha': 0.1, 'h': 20, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:06,471:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,472:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,472:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,473:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,473:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:06,474:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,474:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,475:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,475:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,476:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,477:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,477:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,496:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:06,496:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,497:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,497:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,498:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,498:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,499:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,571:INFO:SMOTE_ENN: Running sampling via ('SMOTE_ENN', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'SMOTE_ENN'}")
# 2022-08-14 19:55:06,572:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,572:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,572:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,573:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,573:INFO:EditedNearestNeighbors: Running noise removal
# 2022-08-14 19:55:06,574:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,574:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,580:INFO:SMOTE_ENN: returning copies for ENN removed too many samples
# 2022-08-14 19:55:06,583:INFO:NEATER: Running sampling via ('NEATER', "{'proportion': 1.0, 'smote_n_neighbors': 5, 'b': 5, 'alpha': 0.1, 'h': 20, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:06,584:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,584:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,584:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,585:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,585:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:06,585:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,586:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,587:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,587:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,588:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,588:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,588:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,606:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:06,606:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,607:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,607:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,607:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,608:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,608:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,609:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,615:INFO:SMOTE_ENN: Running sampling via ('SMOTE_ENN', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'SMOTE_ENN'}")
# 2022-08-14 19:55:06,615:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,615:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,615:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,616:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,616:INFO:EditedNearestNeighbors: Running noise removal
# 2022-08-14 19:55:06,617:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,617:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,622:INFO:SMOTE_ENN: returning copies for ENN removed too many samples
# 2022-08-14 19:55:06,626:INFO:NEATER: Running sampling via ('NEATER', "{'proportion': 1.0, 'smote_n_neighbors': 5, 'b': 5, 'alpha': 0.1, 'h': 20, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:06,626:INFO:SMOTE_ENN: Running sampling via ('SMOTE_ENN', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'SMOTE_ENN'}")
# 2022-08-14 19:55:06,626:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,626:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,627:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,627:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,627:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,627:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,628:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,628:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,628:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:06,629:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,629:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,629:INFO:EditedNearestNeighbors: Running noise removal
# 2022-08-14 19:55:06,629:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,630:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,631:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,631:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,632:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,632:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,633:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,639:INFO:SMOTE_ENN: returning copies for ENN removed too many samples
# 2022-08-14 19:55:06,645:INFO:NEATER: Running sampling via ('NEATER', "{'proportion': 1.0, 'smote_n_neighbors': 5, 'b': 5, 'alpha': 0.1, 'h': 20, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:06,645:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,645:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,646:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,646:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,647:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:06,648:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,648:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,649:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,650:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,650:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,651:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,652:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,661:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:06,661:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,662:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,662:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,663:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,663:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,664:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,664:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,670:INFO:SMOTE_ENN: Running sampling via ('SMOTE_ENN', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'SMOTE_ENN'}")
# 2022-08-14 19:55:06,670:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,670:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,671:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,671:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,672:INFO:EditedNearestNeighbors: Running noise removal
# 2022-08-14 19:55:06,672:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,672:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,676:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:06,677:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,677:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,677:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,677:INFO:SMOTE_ENN: returning copies for ENN removed too many samples
# 2022-08-14 19:55:06,678:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,678:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,678:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,679:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,682:INFO:NEATER: Running sampling via ('NEATER', "{'proportion': 1.0, 'smote_n_neighbors': 5, 'b': 5, 'alpha': 0.1, 'h': 20, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:06,682:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:06,682:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06,682:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:06,683:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:06,684:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:06,684:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:06
 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'n_jobs': 1, 'random_state': None, 'class_name': 'NEATER'}")
# 2022-08-14 19:55:11,430:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-14 19:55:11,431:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,432:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:11,434:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:11,436:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-14 19:55:11,438:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:11,438:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,439:INFO:ADASYN: Running sampling via ('ADASYN', "{'n_neighbors': 5, 'd_th': 0.9, 'beta': 1.0, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'proportion': 1.0, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ADASYN'}")
# 2022-08-14 19:55:11,439:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,440:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:11,441:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:11,452:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,453:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:11,453:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,453:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:11,456:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:11,456:INFO:ADASYN: simplex sampling with n_dim 2
# 2022-08-14 19:55:11,458:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,459:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:11,460:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:11,461:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,368:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:12,368:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:12,369:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:12,370:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,373:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,374:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,386:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,387:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,391:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,392:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,394:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,395:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,455:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2022-08-14 19:55:12,455:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:12,456:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-14 19:55:12,456:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,459:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,459:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,467:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,468:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,471:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,472:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,473:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,474:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-14 19:55:12,475:INFO:Lee: simplex sampling with n_dim 2
# 2022-08-14 19:55:12,475:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski

# %%
results
# Out:
#   database oversampler              classifier  \
# 0   glass0         Lee  DecisionTreeClassifier
# 1   glass0         Lee    KNeighborsClassifier
# 2   yeast1         Lee  DecisionTreeClassifier
# 3   yeast1         Lee    KNeighborsClassifier
#
#                               oversampler_params_key  classifier_module  \
# 0  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...       sklearn.tree
# 1  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...  sklearn.neighbors
# 2  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...       sklearn.tree
# 3  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...  sklearn.neighbors
#
#   classifier_params_key  acc_mean  sens_mean  spec_mean  ppv_mean  ...  \
# 0                    {}  0.782890   0.700000   0.823030  0.662300  ...
# 1                    {}  0.766113   0.764286   0.766749  0.629884  ...
# 2                    {}  0.701804   0.547592   0.764455  0.487282  ...
# 3                    {}  0.722700   0.648016   0.753081  0.515712  ...
#
#      ltn_std    lp_std    ln_std    uc_std  informedness_std  markedness_std  \
# 0   8.831250  0.138899  0.029599  0.024265          0.163764        0.133311
# 1  11.387851  0.138899  0.029599  0.023711          0.144836        0.138675
# 2  38.359694  0.224269  0.300052  0.003819          0.065679        0.063816
# 3  20.315236  0.224269  0.300052  0.004181          0.063380        0.050955
#
#    p_top20_std  brier_std  log_loss_std   auc_std
# 0     0.000000   0.065268      2.254307  0.081882
# 1     0.000000   0.039447      1.451721  0.042586
# 2     0.048895   0.029393      1.015217  0.032840
# 3     0.048895   0.018357      0.663763  0.033304
#
# [4 rows x 58 columns]

# %%
# The results are arranged in a pandas DataFrame with the following columns:

print(results.columns)
# Out:
# Index(['database', 'oversampler', 'classifier', 'oversampler_params_key',
#        'classifier_module', 'classifier_params_key', 'acc_mean', 'sens_mean',
#        'spec_mean', 'ppv_mean', 'npv_mean', 'fpr_mean', 'fdr_mean', 'fnr_mean',
#        'bacc_mean', 'gacc_mean', 'f1_mean', 'mcc_mean', 'l_mean', 'ltp_mean',
#        'lfp_mean', 'lfn_mean', 'ltn_mean', 'lp_mean', 'ln_mean', 'uc_mean',
#        'informedness_mean', 'markedness_mean', 'p_top20_mean', 'brier_mean',
#        'log_loss_mean', 'auc_mean', 'acc_std', 'sens_std', 'spec_std',
#        'ppv_std', 'npv_std', 'fpr_std', 'fdr_std', 'fnr_std', 'bacc_std',
#        'gacc_std', 'f1_std', 'mcc_std', 'l_std', 'ltp_std', 'lfp_std',
#        'lfn_std', 'ltn_std', 'lp_std', 'ln_std', 'uc_std', 'informedness_std',
#        'markedness_std', 'p_top20_std', 'brier_std', 'log_loss_std',
#        'auc_std'],
#       dtype='object')

# %%
# The results can be processed according to the requirements of the analysis

print(results)
# Out:
#   database oversampler              classifier  \
# 0   glass0         Lee  DecisionTreeClassifier
# 1   glass0         Lee    KNeighborsClassifier
# 2   yeast1         Lee  DecisionTreeClassifier
# 3   yeast1         Lee    KNeighborsClassifier
#
#                               oversampler_params_key  classifier_module  \
# 0  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...       sklearn.tree
# 1  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...  sklearn.neighbors
# 2  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...       sklearn.tree
# 3  {'proportion': 1.0, 'n_neighbors': 5, 'nn_para...  sklearn.neighbors
#
#   classifier_params_key  acc_mean  sens_mean  spec_mean  ppv_mean  ...  \
# 0                    {}  0.782890   0.700000   0.823030  0.662300  ...
# 1                    {}  0.766113   0.764286   0.766749  0.629884  ...
# 2                    {}  0.701804   0.547592   0.764455  0.487282  ...
# 3                    {}  0.722700   0.648016   0.753081  0.515712  ...
#
#      ltn_std    lp_std    ln_std    uc_std  informedness_std  markedness_std  \
# 0   8.831250  0.138899  0.029599  0.024265          0.163764        0.133311
# 1  11.387851  0.138899  0.029599  0.023711          0.144836        0.138675
# 2  38.359694  0.224269  0.300052  0.003819          0.065679        0.063816
# 3  20.315236  0.224269  0.300052  0.004181          0.063380        0.050955
#
#    p_top20_std  brier_std  log_loss_std   auc_std
# 0     0.000000   0.065268      2.254307  0.081882
# 1     0.000000   0.039447      1.451721  0.042586
# 2     0.048895   0.029393      1.015217  0.032840
# 3     0.048895   0.018357      0.663763  0.033304
#
# [4 rows x 58 columns]
