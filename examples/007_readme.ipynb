# %% [markdown]
# # Samples codes from the README.rst

# %% [markdown]
# ## Binary oversampling

# %%
import smote_variants as sv
import imbalanced_databases as imbd

dataset= imbd.load_iris0()
X, y= dataset['data'], dataset['target']

oversampler= sv.distance_SMOTE()

# X_samp and y_samp contain the oversampled dataset
X_samp, y_samp= oversampler.sample(X, y)
# Out:
# 2022-08-16 15:45:41.383916: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-16 15:45:41.392465: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-16 15:45:41.392491: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-16 15:45:49,269:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:45:49,275:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:45:49,277:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:45:49,281:INFO:distance_SMOTE: simplex sampling with n_dim 2

# %% [markdown]
# ## Multiclass oversampling

# %%
import smote_variants as sv
import sklearn.datasets as datasets

dataset= datasets.load_wine()
X, y= dataset['data'], dataset['target']

oversampler= sv.MulticlassOversampling(oversampler='distance_SMOTE',
                                       oversampler_params={'random_state': 5})

# X_samp and y_samp contain the oversampled dataset
X_samp, y_samp= oversampler.sample(X, y)
# Out:
# 2022-08-16 15:45:49,586:INFO:MulticlassOversampling: Running multiclass oversampling with strategy eq_1_vs_many_successive
# 2022-08-16 15:45:49,587:INFO:MulticlassOversampling: Sampling minority class with label: 0
# 2022-08-16 15:45:49,589:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': 5, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:45:49,592:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:45:49,593:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:45:49,601:INFO:distance_SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:45:49,603:INFO:MulticlassOversampling: Sampling minority class with label: 2
# 2022-08-16 15:45:49,605:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.24468085106382978, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': 5, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:45:49,609:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:45:49,610:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:45:49,613:INFO:distance_SMOTE: simplex sampling with n_dim 2

# %% [markdown]
# ## Selection of the best oversampler

# %%
import os.path
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import smote_variants as sv
import sklearn.datasets as datasets

dataset= datasets.load_breast_cancer()

dataset= {'data': dataset['data'], 
          'target': dataset['target'], 
          'name': 'breast_cancer'}

classifiers = [('sklearn.neighbors', 'KNeighborsClassifier', {}),
               ('sklearn.tree', 'DecisionTreeClassifier', {})]

oversamplers = sv.queries.get_all_oversamplers(n_quickest=2)

os_params = sv.queries.generate_parameter_combinations(oversamplers, 
                                                       n_max_comb=2)

# samp_obj and cl_obj contain the oversampling and classifier objects which give the
# best performance together
samp_obj, cl_obj= sv.evaluation.model_selection(dataset=dataset,
                                                oversamplers=os_params,
                                                classifiers=classifiers,
                                                validator_params={'n_splits': 2,
                                                                  'n_repeats': 1},
                                                n_jobs= 5)

# training the best techniques using the entire dataset
X_samp, y_samp= samp_obj.sample(dataset['data'], 
                                dataset['target'])
cl_obj.fit(X_samp, y_samp)
# Out:
# 2022-08-16 15:45:53.103528: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-16 15:45:53.111998: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-16 15:45:53.112817: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-16 15:45:53.170340: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-16 15:45:53.184347: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-16 15:45:53.185267: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-16 15:45:59,433:INFO:DSRBF: Running sampling via ('DSRBF', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'hidden_range': (4, 10), 'i_b': 2.0, 'o_b': 2.0, 'n_pop': 100, 'n_init_pop': 1000, 'n_iter': 40, 'n_sampling_epoch': 8, 'n_jobs': 1, 'random_state': None, 'class_name': 'DSRBF'}")
# 2022-08-16 15:45:59,434:INFO:DSRBF: Running sampling via ('DSRBF', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'hidden_range': (4, 10), 'i_b': 2.0, 'o_b': 2.0, 'n_pop': 100, 'n_init_pop': 1000, 'n_iter': 40, 'n_sampling_epoch': 8, 'n_jobs': 1, 'random_state': None, 'class_name': 'DSRBF'}")
# 2022-08-16 15:45:59,434:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:45:59,434:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:45:59,435:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:45:59,435:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:45:59,435:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:45:59,435:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:45:59,506:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:45:59,511:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:00,596:INFO:DSRBF: Iteration 0/40, loss: 0.902531, data size: 320
# 2022-08-16 15:46:00,624:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:00,625:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:00,626:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:00,628:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:00,681:INFO:DSRBF: Iteration 0/40, loss: 0.885398, data size: 321
# 2022-08-16 15:46:00,709:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:00,711:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:00,711:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:00,712:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:01,292:INFO:DSRBF: Iteration 1/40, loss: 0.885398, data size: 321
# 2022-08-16 15:46:01,298:INFO:DSRBF: Iteration 1/40, loss: 0.902531, data size: 320
# 2022-08-16 15:46:01,506:INFO:DSRBF: Iteration 2/40, loss: 0.858200, data size: 320
# 2022-08-16 15:46:01,511:INFO:DSRBF: Iteration 2/40, loss: 0.597627, data size: 321
# 2022-08-16 15:46:01,609:INFO:DSRBF: Iteration 3/40, loss: 0.682382, data size: 320
# 2022-08-16 15:46:01,615:INFO:DSRBF: Iteration 3/40, loss: 0.597627, data size: 321
# 2022-08-16 15:46:01,703:INFO:DSRBF: Iteration 4/40, loss: 0.682382, data size: 320
# 2022-08-16 15:46:01,719:INFO:DSRBF: Iteration 4/40, loss: 0.463268, data size: 321
# 2022-08-16 15:46:01,807:INFO:DSRBF: Iteration 5/40, loss: 0.682382, data size: 320
# 2022-08-16 15:46:01,846:INFO:DSRBF: Iteration 5/40, loss: 0.463268, data size: 321
# 2022-08-16 15:46:02,065:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:02,066:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:02,067:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:02,068:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:02,096:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:02,097:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:02,098:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:02,099:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:02,734:INFO:DSRBF: Iteration 6/40, loss: 0.463268, data size: 321
# 2022-08-16 15:46:02,734:INFO:DSRBF: Iteration 6/40, loss: 0.606061, data size: 320
# 2022-08-16 15:46:02,941:INFO:DSRBF: Iteration 7/40, loss: 0.606061, data size: 320
# 2022-08-16 15:46:02,973:INFO:DSRBF: Iteration 7/40, loss: 0.463268, data size: 321
# 2022-08-16 15:46:03,037:INFO:DSRBF: Iteration 8/40, loss: 0.606061, data size: 320
# 2022-08-16 15:46:03,063:INFO:DSRBF: Iteration 8/40, loss: 0.463268, data size: 321
# 2022-08-16 15:46:03,130:INFO:DSRBF: Iteration 9/40, loss: 0.606061, data size: 320
# 2022-08-16 15:46:03,159:INFO:DSRBF: Iteration 9/40, loss: 0.450849, data size: 321
# 2022-08-16 15:46:03,232:INFO:DSRBF: Iteration 10/40, loss: 0.606061, data size: 320
# 2022-08-16 15:46:03,253:INFO:DSRBF: Iteration 10/40, loss: 0.450849, data size: 321
# 2022-08-16 15:46:03,322:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:03,323:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:03,323:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:03,324:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:03,334:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:03,335:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:03,335:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:03,337:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:03,944:INFO:DSRBF: Iteration 11/40, loss: 0.563081, data size: 320
# 2022-08-16 15:46:03,980:INFO:DSRBF: Iteration 11/40, loss: 0.450849, data size: 321
# 2022-08-16 15:46:04,182:INFO:DSRBF: Iteration 12/40, loss: 0.507669, data size: 320
# 2022-08-16 15:46:04,209:INFO:DSRBF: Iteration 12/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:04,290:INFO:DSRBF: Iteration 13/40, loss: 0.507669, data size: 320
# 2022-08-16 15:46:04,301:INFO:DSRBF: Iteration 13/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:04,404:INFO:DSRBF: Iteration 14/40, loss: 0.507669, data size: 320
# 2022-08-16 15:46:04,407:INFO:DSRBF: Iteration 14/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:04,523:INFO:DSRBF: Iteration 15/40, loss: 0.507669, data size: 320
# 2022-08-16 15:46:04,524:INFO:DSRBF: Iteration 15/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:04,613:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:04,614:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:04,615:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:04,616:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:04,629:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:04,630:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:04,630:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:04,632:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:05,261:INFO:DSRBF: Iteration 16/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:05,308:INFO:DSRBF: Iteration 16/40, loss: 0.507669, data size: 320
# 2022-08-16 15:46:05,513:INFO:DSRBF: Iteration 17/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:05,571:INFO:DSRBF: Iteration 17/40, loss: 0.475007, data size: 320
# 2022-08-16 15:46:05,610:INFO:DSRBF: Iteration 18/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:05,671:INFO:DSRBF: Iteration 18/40, loss: 0.475007, data size: 320
# 2022-08-16 15:46:05,702:INFO:DSRBF: Iteration 19/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:05,775:INFO:DSRBF: Iteration 19/40, loss: 0.475007, data size: 320
# 2022-08-16 15:46:05,801:INFO:DSRBF: Iteration 20/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:05,885:INFO:DSRBF: Iteration 20/40, loss: 0.475007, data size: 320
# 2022-08-16 15:46:05,901:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:05,902:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:05,903:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:05,904:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:06,001:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:06,002:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:06,002:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:06,003:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:06,505:INFO:DSRBF: Iteration 21/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:06,721:INFO:DSRBF: Iteration 22/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:06,769:INFO:DSRBF: Iteration 21/40, loss: 0.475007, data size: 320
# 2022-08-16 15:46:06,890:INFO:DSRBF: Iteration 23/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:06,990:INFO:DSRBF: Iteration 22/40, loss: 0.457919, data size: 320
# 2022-08-16 15:46:07,018:INFO:DSRBF: Iteration 24/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:07,093:INFO:DSRBF: Iteration 23/40, loss: 0.457919, data size: 320
# 2022-08-16 15:46:07,108:INFO:DSRBF: Iteration 25/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:07,192:INFO:DSRBF: Iteration 24/40, loss: 0.451639, data size: 320
# 2022-08-16 15:46:07,215:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:07,216:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:07,217:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:07,218:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:07,291:INFO:DSRBF: Iteration 25/40, loss: 0.451639, data size: 320
# 2022-08-16 15:46:07,387:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:07,387:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:07,388:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:07,389:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:08,037:INFO:DSRBF: Iteration 26/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:08,154:INFO:DSRBF: Iteration 26/40, loss: 0.451639, data size: 320
# 2022-08-16 15:46:08,260:INFO:DSRBF: Iteration 27/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:08,357:INFO:DSRBF: Iteration 28/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:08,406:INFO:DSRBF: Iteration 27/40, loss: 0.451639, data size: 320
# 2022-08-16 15:46:08,455:INFO:DSRBF: Iteration 29/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:08,524:INFO:DSRBF: Iteration 28/40, loss: 0.438447, data size: 320
# 2022-08-16 15:46:08,565:INFO:DSRBF: Iteration 30/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:08,636:INFO:DSRBF: Iteration 29/40, loss: 0.438447, data size: 320
# 2022-08-16 15:46:08,664:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:08,665:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:08,666:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:08,667:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:08,757:INFO:DSRBF: Iteration 30/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:08,877:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:08,878:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:08,878:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:08,880:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:09,357:INFO:DSRBF: Iteration 31/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:09,556:INFO:DSRBF: Iteration 31/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:09,616:INFO:DSRBF: Iteration 32/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:09,716:INFO:DSRBF: Iteration 33/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:09,806:INFO:DSRBF: Iteration 32/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:09,812:INFO:DSRBF: Iteration 34/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:09,912:INFO:DSRBF: Iteration 35/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:09,915:INFO:DSRBF: Iteration 33/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:10,000:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:10,001:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:10,003:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:10,004:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:10,020:INFO:DSRBF: Iteration 34/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:10,124:INFO:DSRBF: Iteration 35/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:10,234:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:10,234:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:10,234:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:10,235:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:10,668:INFO:DSRBF: Iteration 36/40, loss: 0.396259, data size: 321
# 2022-08-16 15:46:10,874:INFO:DSRBF: Iteration 36/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:10,888:INFO:DSRBF: Iteration 37/40, loss: 0.380441, data size: 321
# 2022-08-16 15:46:10,998:INFO:DSRBF: Iteration 38/40, loss: 0.380441, data size: 321
# 2022-08-16 15:46:11,093:INFO:DSRBF: Iteration 39/40, loss: 0.380441, data size: 321
# 2022-08-16 15:46:11,102:INFO:DSRBF: Iteration 37/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:11,209:INFO:DSRBF: Iteration 38/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:11,286:INFO:DSRBF: Running sampling via ('DSRBF', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'hidden_range': (4, 10), 'i_b': 2.0, 'o_b': 2.0, 'n_pop': 100, 'n_init_pop': 1000, 'n_iter': 40, 'n_sampling_epoch': 8, 'n_jobs': 1, 'random_state': None, 'class_name': 'DSRBF'}")
# 2022-08-16 15:46:11,305:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:11,305:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:11,305:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:11,306:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:11,314:INFO:DSRBF: Iteration 39/40, loss: 0.423644, data size: 320
# 2022-08-16 15:46:11,568:INFO:DSRBF: Running sampling via ('DSRBF', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'hidden_range': (4, 10), 'i_b': 2.0, 'o_b': 2.0, 'n_pop': 100, 'n_init_pop': 1000, 'n_iter': 40, 'n_sampling_epoch': 8, 'n_jobs': 1, 'random_state': None, 'class_name': 'DSRBF'}")
# 2022-08-16 15:46:11,570:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:11,570:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:11,571:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:11,571:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:12,556:INFO:DSRBF: Iteration 0/40, loss: 0.956342, data size: 339
# 2022-08-16 15:46:12,582:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:12,583:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:12,584:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:12,585:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:12,825:INFO:DSRBF: Iteration 0/40, loss: 0.937987, data size: 338
# 2022-08-16 15:46:12,869:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:12,870:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:12,870:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:12,871:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:13,239:INFO:DSRBF: Iteration 1/40, loss: 0.956342, data size: 339
# 2022-08-16 15:46:13,421:INFO:DSRBF: Iteration 1/40, loss: 0.937987, data size: 338
# 2022-08-16 15:46:13,428:INFO:DSRBF: Iteration 2/40, loss: 0.653954, data size: 339
# 2022-08-16 15:46:13,549:INFO:DSRBF: Iteration 3/40, loss: 0.653954, data size: 339
# 2022-08-16 15:46:13,634:INFO:DSRBF: Iteration 4/40, loss: 0.597497, data size: 339
# 2022-08-16 15:46:13,644:INFO:DSRBF: Iteration 2/40, loss: 0.774812, data size: 338
# 2022-08-16 15:46:13,718:INFO:DSRBF: Iteration 5/40, loss: 0.597497, data size: 339
# 2022-08-16 15:46:13,725:INFO:DSRBF: Iteration 3/40, loss: 0.609039, data size: 338
# 2022-08-16 15:46:13,812:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:13,813:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:13,814:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:13,815:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:13,832:INFO:DSRBF: Iteration 4/40, loss: 0.609039, data size: 338
# 2022-08-16 15:46:13,929:INFO:DSRBF: Iteration 5/40, loss: 0.609039, data size: 338
# 2022-08-16 15:46:14,165:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:14,166:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:14,166:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:14,168:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:14,484:INFO:DSRBF: Iteration 6/40, loss: 0.597497, data size: 339
# 2022-08-16 15:46:14,718:INFO:DSRBF: Iteration 7/40, loss: 0.597497, data size: 339
# 2022-08-16 15:46:14,818:INFO:DSRBF: Iteration 6/40, loss: 0.609039, data size: 338
# 2022-08-16 15:46:14,819:INFO:DSRBF: Iteration 8/40, loss: 0.597497, data size: 339
# 2022-08-16 15:46:14,918:INFO:DSRBF: Iteration 9/40, loss: 0.587065, data size: 339
# 2022-08-16 15:46:15,020:INFO:DSRBF: Iteration 7/40, loss: 0.571842, data size: 338
# 2022-08-16 15:46:15,030:INFO:DSRBF: Iteration 10/40, loss: 0.562846, data size: 339
# 2022-08-16 15:46:15,116:INFO:DSRBF: Iteration 8/40, loss: 0.571842, data size: 338
# 2022-08-16 15:46:15,133:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:15,134:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:15,134:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:15,135:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:15,225:INFO:DSRBF: Iteration 9/40, loss: 0.571842, data size: 338
# 2022-08-16 15:46:15,347:INFO:DSRBF: Iteration 10/40, loss: 0.571842, data size: 338
# 2022-08-16 15:46:15,450:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:15,451:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:15,454:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:15,456:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:15,855:INFO:DSRBF: Iteration 11/40, loss: 0.562846, data size: 339
# 2022-08-16 15:46:16,098:INFO:DSRBF: Iteration 12/40, loss: 0.477483, data size: 339
# 2022-08-16 15:46:16,144:INFO:DSRBF: Iteration 11/40, loss: 0.571842, data size: 338
# 2022-08-16 15:46:16,216:INFO:DSRBF: Iteration 13/40, loss: 0.477483, data size: 339
# 2022-08-16 15:46:16,318:INFO:DSRBF: Iteration 14/40, loss: 0.476094, data size: 339
# 2022-08-16 15:46:16,364:INFO:DSRBF: Iteration 12/40, loss: 0.536757, data size: 338
# 2022-08-16 15:46:16,439:INFO:DSRBF: Iteration 15/40, loss: 0.476094, data size: 339
# 2022-08-16 15:46:16,460:INFO:DSRBF: Iteration 13/40, loss: 0.536757, data size: 338
# 2022-08-16 15:46:16,555:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:16,555:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:16,556:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:16,556:INFO:DSRBF: Iteration 14/40, loss: 0.536757, data size: 338
# 2022-08-16 15:46:16,558:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:16,653:INFO:DSRBF: Iteration 15/40, loss: 0.536757, data size: 338
# 2022-08-16 15:46:16,750:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:16,751:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:16,752:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:16,753:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:17,198:INFO:DSRBF: Iteration 16/40, loss: 0.476094, data size: 339
# 2022-08-16 15:46:17,438:INFO:DSRBF: Iteration 17/40, loss: 0.476094, data size: 339
# 2022-08-16 15:46:17,450:INFO:DSRBF: Iteration 16/40, loss: 0.470238, data size: 338
# 2022-08-16 15:46:17,558:INFO:DSRBF: Iteration 18/40, loss: 0.436328, data size: 339
# 2022-08-16 15:46:17,675:INFO:DSRBF: Iteration 17/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:17,710:INFO:DSRBF: Iteration 19/40, loss: 0.436328, data size: 339
# 2022-08-16 15:46:17,783:INFO:DSRBF: Iteration 18/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:17,820:INFO:DSRBF: Iteration 20/40, loss: 0.436328, data size: 339
# 2022-08-16 15:46:17,878:INFO:DSRBF: Iteration 19/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:17,934:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:17,934:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:17,935:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:17,936:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:17,965:INFO:DSRBF: Iteration 20/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:18,069:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:18,070:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:18,070:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:18,071:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:18,631:INFO:DSRBF: Iteration 21/40, loss: 0.436328, data size: 339
# 2022-08-16 15:46:18,835:INFO:DSRBF: Iteration 21/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:18,887:INFO:DSRBF: Iteration 22/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:18,990:INFO:DSRBF: Iteration 23/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:19,070:INFO:DSRBF: Iteration 22/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:19,117:INFO:DSRBF: Iteration 24/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:19,167:INFO:DSRBF: Iteration 23/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:19,232:INFO:DSRBF: Iteration 25/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:19,263:INFO:DSRBF: Iteration 24/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:19,364:INFO:DSRBF: Iteration 25/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:19,366:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:19,367:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:19,368:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:19,369:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:19,485:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:19,486:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:19,487:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:19,487:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:20,010:INFO:DSRBF: Iteration 26/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:20,126:INFO:DSRBF: Iteration 26/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:20,233:INFO:DSRBF: Iteration 27/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:20,345:INFO:DSRBF: Iteration 28/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:20,351:INFO:DSRBF: Iteration 27/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:20,447:INFO:DSRBF: Iteration 29/40, loss: 0.434101, data size: 339
# 2022-08-16 15:46:20,448:INFO:DSRBF: Iteration 28/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:20,680:INFO:DSRBF: Iteration 29/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:20,683:INFO:DSRBF: Iteration 30/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:20,804:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:20,805:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:20,805:INFO:DSRBF: Iteration 30/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:20,806:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:20,807:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:20,931:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:20,932:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:20,933:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:20,934:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:21,632:INFO:DSRBF: Iteration 31/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:21,699:INFO:DSRBF: Iteration 31/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:21,850:INFO:DSRBF: Iteration 32/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:21,962:INFO:DSRBF: Iteration 32/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:21,962:INFO:DSRBF: Iteration 33/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:22,052:INFO:DSRBF: Iteration 34/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:22,066:INFO:DSRBF: Iteration 33/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:22,196:INFO:DSRBF: Iteration 35/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:22,236:INFO:DSRBF: Iteration 34/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:22,293:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:22,294:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:22,295:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:22,296:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:22,376:INFO:DSRBF: Iteration 35/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:22,486:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.75, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:22,487:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:22,487:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:22,488:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:22,956:INFO:DSRBF: Iteration 36/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:23,151:INFO:DSRBF: Iteration 36/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:23,177:INFO:DSRBF: Iteration 37/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:23,289:INFO:DSRBF: Iteration 38/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:23,397:INFO:DSRBF: Iteration 37/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:23,398:INFO:DSRBF: Iteration 39/40, loss: 0.413120, data size: 339
# 2022-08-16 15:46:23,513:INFO:DSRBF: Iteration 38/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:23,618:INFO:DSRBF: Iteration 39/40, loss: 0.433128, data size: 338
# 2022-08-16 15:46:23,631:INFO:AMSCO: Running sampling via ('AMSCO', "{'n_pop': 5, 'n_iter': 15, 'omega': 0.1, 'r1': 0.1, 'r2': 0.1, 'nn_params': {}, 'n_jobs': 1, 'classifier': ('sklearn.tree', 'DecisionTreeClassifier', {'random_state': 2}), 'random_state': None, 'class_name': 'AMSCO'}")
# 2022-08-16 15:46:23,632:INFO:AMSCO starting iteration 0
# 2022-08-16 15:46:23,633:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0005432623496926, 'n_neighbors': 7, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,634:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,634:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,639:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,661:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.1150911626304016, 'n_neighbors': 4, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,661:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,662:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,662:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,684:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0017796701135897, 'n_neighbors': 4, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,685:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,685:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,686:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,712:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7086116880185391, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,713:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,715:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,716:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,736:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.1374471276100464, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,736:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,737:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,738:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,766:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.1556163696806876, 'n_neighbors': 9, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,767:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,769:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,770:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,790:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.280577715441461, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,791:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,792:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,793:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,815:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.1569651781503936, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,816:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,817:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,818:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,821:INFO:AMSCO: Running sampling via ('AMSCO', "{'n_pop': 5, 'n_iter': 15, 'omega': 0.1, 'r1': 0.1, 'r2': 0.1, 'nn_params': {}, 'n_jobs': 1, 'classifier': ('sklearn.tree', 'DecisionTreeClassifier', {'random_state': 2}), 'random_state': None, 'class_name': 'AMSCO'}")
# 2022-08-16 15:46:23,822:INFO:AMSCO starting iteration 0
# 2022-08-16 15:46:23,823:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.6125083523332083, 'n_neighbors': 8, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,823:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,824:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,827:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,848:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.8371455613194292, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,849:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,849:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,850:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,851:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.6420445524900906, 'n_neighbors': 5, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,852:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,853:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,854:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,878:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9964126353322825, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,879:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,879:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,880:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,883:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.3049660408738009, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,884:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,884:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,885:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,904:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.1136446166549783, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,905:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,905:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,906:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,911:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.3110245539844112, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,912:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,912:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,913:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,932:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.027691890822099, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,933:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,933:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:46:23,933:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.462948000506355, 'n_neighbors': 6, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:46:23,934:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:46:23,934:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:46:23,934:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# ...
# 2022-08-16 15:47:13,427:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,427:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,428:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,464:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 3.7147066119577796, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,465:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,465:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,466:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,504:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 3.944963959541127, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,505:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,506:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,507:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,540:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 3.975494658426242, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,540:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,541:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,542:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,579:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 3.917525733967856, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,579:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,580:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,581:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,618:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 3.622778668822572, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,618:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,618:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,619:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,688:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 3.9501005258516373, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,689:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,689:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,691:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,738:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 4.0, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,739:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,739:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,740:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,778:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 4.0, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,779:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,779:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,780:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,825:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 4.0, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,825:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,826:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,826:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,865:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 4.0, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,865:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,865:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,866:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:13,905:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 4.0, 'n_neighbors': 10, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:13,905:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:13,906:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:13,907:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:14,029:INFO:AMSCO: fitness scores: 0.940158 0.953513 0.940158 0.953513
# 2022-08-16 15:47:14,375:INFO:DSRBF: Running sampling via ('DSRBF', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {}, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': None}, 'hidden_range': (4, 10), 'i_b': 2.0, 'o_b': 2.0, 'n_pop': 100, 'n_init_pop': 1000, 'n_iter': 40, 'n_sampling_epoch': 8, 'n_jobs': 1, 'random_state': None, 'class_name': 'DSRBF'}")
# 2022-08-16 15:47:14,379:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:14,380:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:14,381:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:14,751:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:47:33,764:INFO:DSRBF: Iteration 0/40, loss: 0.927058, data size: 641
# 2022-08-16 15:47:33,810:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:47:33,825:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:47:33,826:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:47:34,002:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:48:02,484:INFO:DSRBF: Iteration 1/40, loss: 0.927058, data size: 641
# 2022-08-16 15:48:02,856:INFO:DSRBF: Iteration 2/40, loss: 0.775192, data size: 641
# 2022-08-16 15:48:02,962:INFO:DSRBF: Iteration 3/40, loss: 0.775192, data size: 641
# 2022-08-16 15:48:03,105:INFO:DSRBF: Iteration 4/40, loss: 0.712809, data size: 641
# 2022-08-16 15:48:03,310:INFO:DSRBF: Iteration 5/40, loss: 0.704617, data size: 641
# 2022-08-16 15:48:03,463:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:48:03,465:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:48:03,466:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:48:03,734:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:48:13,106:INFO:DSRBF: Iteration 6/40, loss: 0.667472, data size: 641
# 2022-08-16 15:48:13,543:INFO:DSRBF: Iteration 7/40, loss: 0.619547, data size: 641
# 2022-08-16 15:48:13,705:INFO:DSRBF: Iteration 8/40, loss: 0.619547, data size: 641
# 2022-08-16 15:48:13,870:INFO:DSRBF: Iteration 9/40, loss: 0.558766, data size: 641
# 2022-08-16 15:48:14,461:INFO:DSRBF: Iteration 10/40, loss: 0.558766, data size: 641
# 2022-08-16 15:48:14,658:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:48:14,660:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:48:14,661:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:48:14,784:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:48:40,802:INFO:DSRBF: Iteration 11/40, loss: 0.558766, data size: 641
# 2022-08-16 15:48:41,108:INFO:DSRBF: Iteration 12/40, loss: 0.558766, data size: 641
# 2022-08-16 15:48:41,226:INFO:DSRBF: Iteration 13/40, loss: 0.516656, data size: 641
# 2022-08-16 15:48:41,371:INFO:DSRBF: Iteration 14/40, loss: 0.516656, data size: 641
# 2022-08-16 15:48:41,666:INFO:DSRBF: Iteration 15/40, loss: 0.516656, data size: 641
# 2022-08-16 15:48:41,869:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:48:41,870:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:48:41,871:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:48:41,974:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:49:09,888:INFO:DSRBF: Iteration 16/40, loss: 0.516656, data size: 641
# 2022-08-16 15:49:10,197:INFO:DSRBF: Iteration 17/40, loss: 0.516656, data size: 641
# 2022-08-16 15:49:10,315:INFO:DSRBF: Iteration 18/40, loss: 0.492732, data size: 641
# 2022-08-16 15:49:10,427:INFO:DSRBF: Iteration 19/40, loss: 0.492732, data size: 641
# 2022-08-16 15:49:10,718:INFO:DSRBF: Iteration 20/40, loss: 0.492732, data size: 641
# 2022-08-16 15:49:10,852:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:49:10,853:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:49:10,854:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:49:11,052:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:49:43,744:INFO:DSRBF: Iteration 21/40, loss: 0.492732, data size: 641
# 2022-08-16 15:49:44,140:INFO:DSRBF: Iteration 22/40, loss: 0.448735, data size: 641
# 2022-08-16 15:49:44,281:INFO:DSRBF: Iteration 23/40, loss: 0.448735, data size: 641
# 2022-08-16 15:49:44,437:INFO:DSRBF: Iteration 24/40, loss: 0.448735, data size: 641
# 2022-08-16 15:49:44,710:INFO:DSRBF: Iteration 25/40, loss: 0.448735, data size: 641
# 2022-08-16 15:49:44,947:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:49:44,948:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:49:44,950:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:49:45,216:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:50:29,247:INFO:DSRBF: Iteration 26/40, loss: 0.448735, data size: 641
# 2022-08-16 15:50:29,741:INFO:DSRBF: Iteration 27/40, loss: 0.448735, data size: 641
# 2022-08-16 15:50:30,089:INFO:DSRBF: Iteration 28/40, loss: 0.448735, data size: 641
# 2022-08-16 15:50:30,440:INFO:DSRBF: Iteration 29/40, loss: 0.448735, data size: 641
# 2022-08-16 15:50:31,066:INFO:DSRBF: Iteration 30/40, loss: 0.448735, data size: 641
# 2022-08-16 15:50:31,543:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:50:31,555:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:50:31,566:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:50:31,845:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:51:03,014:INFO:DSRBF: Iteration 31/40, loss: 0.448735, data size: 641
# 2022-08-16 15:51:03,296:INFO:DSRBF: Iteration 32/40, loss: 0.442226, data size: 641
# 2022-08-16 15:51:03,498:INFO:DSRBF: Iteration 33/40, loss: 0.442226, data size: 641
# 2022-08-16 15:51:03,681:INFO:DSRBF: Iteration 34/40, loss: 0.442226, data size: 641
# 2022-08-16 15:51:03,826:INFO:DSRBF: Iteration 35/40, loss: 0.435492, data size: 641
# 2022-08-16 15:51:04,036:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 3, 'nn_params': {'metric_tensor': None}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2022-08-16 15:51:04,048:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:04,068:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:04,256:INFO:SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:51:30,952:INFO:DSRBF: Iteration 36/40, loss: 0.435492, data size: 641
# 2022-08-16 15:51:31,244:INFO:DSRBF: Iteration 37/40, loss: 0.435492, data size: 641
# 2022-08-16 15:51:31,387:INFO:DSRBF: Iteration 38/40, loss: 0.435492, data size: 641
# 2022-08-16 15:51:31,537:INFO:DSRBF: Iteration 39/40, loss: 0.435492, data size: 641
# KNeighborsClassifier()

# %% [markdown]
# ## Integration with sklearn pipelines

# %%
import smote_variants as sv
import imblearn.datasets as imb_datasets

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

libras= imb_datasets.fetch_datasets()['libras_move']
X, y= libras['data'], libras['target']

oversampler = ('smote_variants', 'MulticlassOversampling', 
                {'oversampler': 'distance_SMOTE', 'oversampler_params': {}})

classifier = ('sklearn.neighbors', 'KNeighborsClassifier', {})

# Constructing a pipeline which contains oversampling and classification 
# as the last step.
model= Pipeline([('scale', StandardScaler()), 
                 ('clf', sv.classifiers.OversamplingClassifier(oversampler, classifier))])

model.fit(X, y)
# Out:
# 2022-08-16 15:51:40,282:INFO:MulticlassOversampling: Running multiclass oversampling with strategy eq_1_vs_many_successive
# 2022-08-16 15:51:40,310:INFO:MulticlassOversampling: Sampling minority class with label: 1
# 2022-08-16 15:51:40,318:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:40,320:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:40,323:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:40,446:INFO:distance_SMOTE: simplex sampling with n_dim 2
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('clf',
#                  OversamplingClassifier(classifier=('sklearn.neighbors',
#                                                     'KNeighborsClassifier',
#                                                     {}),
#                                         oversampler=('smote_variants',
#                                                      'MulticlassOversampling',
#                                                      {'oversampler': 'distance_SMOTE',
#                                                       'oversampler_params': {}})))])

# %% [markdown]
# ## Integration with sklearn grid search

# %%
import smote_variants as sv
import imblearn.datasets as imb_datasets

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

libras= imb_datasets.fetch_datasets()['libras_move']
X, y= libras['data'], libras['target']

oversampler = ('smote_variants', 'MulticlassOversampling', 
                {'oversampler': 'distance_SMOTE', 'oversampler_params': {}})

classifier = ('sklearn.neighbors', 'KNeighborsClassifier', {})

# Constructing a pipeline with oversampling and classification as the last step
model= Pipeline([('scale', StandardScaler()), 
                 ('clf', sv.classifiers.OversamplingClassifier(oversampler, classifier))])

param_grid= {'clf__oversampler':[('smote_variants', 'distance_SMOTE', {'proportion': 0.5}),
                                 ('smote_variants', 'distance_SMOTE', {'proportion': 1.0}),
                                 ('smote_variants', 'distance_SMOTE', {'proportion': 1.5})]}

# Specifying the gridsearch for model selection
grid= GridSearchCV(model, 
                   param_grid=param_grid, 
                   cv=3, 
                   n_jobs=1, 
                   verbose=2, 
                   scoring='accuracy')

# Fitting the pipeline
grid.fit(X, y)
# Out:
# 2022-08-16 15:51:42,019:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:42,021:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:42,024:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:42,105:INFO:distance_SMOTE: simplex sampling with n_dim 2
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# 2022-08-16 15:51:42,355:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:42,360:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:42,362:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:42,434:INFO:distance_SMOTE: simplex sampling with n_dim 2
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 0.5}); total time=   0.3s
# 2022-08-16 15:51:42,714:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:42,716:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:42,721:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:42,895:INFO:distance_SMOTE: simplex sampling with n_dim 2
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 0.5}); total time=   0.4s
# 2022-08-16 15:51:43,099:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:43,100:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:43,101:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:43,175:INFO:distance_SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:51:43,267:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:43,269:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:43,271:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 0.5}); total time=   0.4s
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 1.0}); total time=   0.2s
# 2022-08-16 15:51:43,414:INFO:distance_SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:51:43,529:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:43,530:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:43,531:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:43,651:INFO:distance_SMOTE: simplex sampling with n_dim 2
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 1.0}); total time=   0.3s
# 2022-08-16 15:51:43,890:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:43,891:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:43,892:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:43,906:INFO:distance_SMOTE: simplex sampling with n_dim 2
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 1.0}); total time=   0.4s
# 2022-08-16 15:51:44,122:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:44,123:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:44,124:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:44,144:INFO:distance_SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:51:44,230:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:44,231:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:44,232:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 1.5}); total time=   0.2s
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 1.5}); total time=   0.1s
# 2022-08-16 15:51:44,364:INFO:distance_SMOTE: simplex sampling with n_dim 2
# 2022-08-16 15:51:44,498:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'uniform', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2022-08-16 15:51:44,499:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2022-08-16 15:51:44,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2022-08-16 15:51:44,645:INFO:distance_SMOTE: simplex sampling with n_dim 2
# [CV] END clf__oversampler=('smote_variants', 'distance_SMOTE', {'proportion': 1.5}); total time=   0.3s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('clf',
#                                         OversamplingClassifier(classifier=('sklearn.neighbors',
#                                                                            'KNeighborsClassifier',
#                                                                            {}),
#                                                                oversampler=('smote_variants',
#                                                                             'MulticlassOversampling',
#                                                                             {'oversampler': 'distance_SMOTE',
#                                                                              'oversampler_params': {}})))]),
#              n_jobs=1,
#              param_grid={'clf__oversampler': [('smote_variants',
#                                                'distance_SMOTE',
#                                                {'proportion': 0.5}),
#                                               ('smote_variants',
#                                                'distance_SMOTE',
#                                                {'proportion': 1.0}),
#                                               ('smote_variants',
#                                                'distance_SMOTE',
#                                                {'proportion': 1.5})]},
#              scoring='accuracy', verbose=2)
